# %%
import os
import time
import boto3
import sagemaker
import pandas as pd
## SageMaker dependencies
import sagemaker
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.image_uris import retrieve

## This instantiates a SageMaker session that we will be operating in.
session = sagemaker.Session()
role = sagemaker.get_execution_role()

# %% [markdown]
# # Configuring the built-in Linear Learner algorithm

# %% [markdown]
# First, let\'s retrieve the datasets from the previous notebook.

# %%
# %store -r X_train
# %store -r X_test
# %store -r X_val
# %store -r Y_train
# %store -r Y_test
# %store -r Y_val

# %% [markdown]
# Now we need to do a simple thing: Upload the training and Validation set to S3m since the instances that SageMaker spin up will get the data from there. There is an OPTIONAL step for performance gains to transform to RecordIO format, if you are curious check the documentation!
#
# For Built-in algorithms there is a convention that **the first column is the target column**

# %%
data_dir = "data/"
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

prefix = "boston-dataset"
pd.concat([Y_train, X_train], axis=1).to_csv(
    os.path.join(data_dir, "train.csv"), header=False, index=False
)
pd.concat([Y_val, X_val], axis=1).to_csv(
    os.path.join(data_dir, "validation.csv"), header=False, index=False
)

val_location = session.upload_data(os.path.join(data_dir, "validation.csv"), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, "train.csv"), key_prefix=prefix)

# %% [markdown]
# Now we will create a pointer to the data in the Jupyter Lab. You could read from YOUR S3 as well.

# %%
s3_input_train = TrainingInput(s3_data=train_location, content_type="text/csv")
s3_input_validation = TrainingInput(s3_data=val_location, content_type="text/csv")

# %% [markdown]
# ## Set an Estimator

# %% [markdown]
# To use a built-in algorithm we only need instantiate the Estimator class appropiatedly. Most of this parameters can be copy-pasted since are standard.
# The training job will spin an instance of the given type to run the training command.

# %%
container = retrieve(framework='linear-learner', region=session.boto_region_name, version="latest")

model = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m5.large",
    output_path="s3://{}/{}/output".format(session.default_bucket(), prefix),
    sagemaker_session=session,
)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.

# %% [markdown]
# ## Configure Hyperparameters

# %% [markdown]
# It may be confusing, but SageMaker names hyperparameters as the parameters of the model and what the ML community names hyperparameters.
# At this point we will later configure the auto-hyperparameter optimization jobs.

# %%
model.set_hyperparameters(
    feature_dim=X_train.shape[1], predictor_type="regressor", mini_batch_size=100
)

# %% [markdown]
# ## Train

# %% [markdown]
# Let's train the model. If we specify the validation set to SageMaker, a bunch of interesting metrics will be outputted.

# %%
model.fit({"train": s3_input_train, "validation": s3_input_validation}, wait=True)
# Out:
# 2021-09-07 02:45:33 Starting - Starting the training job...
# 2021-09-07 02:45:35 Starting - Launching requested ML instancesProfilerReport-1630982733: InProgress
# ......
# 2021-09-07 02:46:50 Starting - Preparing the instances for training.........
# 2021-09-07 02:48:31 Downloading - Downloading input data...
# 2021-09-07 02:48:51 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/07/2021 02:49:13 INFO 140620455696192] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [09/07/2021 02:49:13 INFO 140620455696192] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '13', 'predictor_type': 'regressor', 'mini_batch_size': '100'}
# [09/07/2021 02:49:13 INFO 140620455696192] Final configuration: {'mini_batch_size': '100', 'epochs': '15', 'feature_dim': '13', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [09/07/2021 02:49:13 WARNING 140620455696192] Loggers have already been setup.
# Process 1 is a worker.
# [09/07/2021 02:49:13 INFO 140620455696192] Using default worker.
# [09/07/2021 02:49:14 INFO 140620455696192] Checkpoint loading and saving are disabled.
# [09/07/2021 02:49:14 INFO 140620455696192] Create Store: local
# [09/07/2021 02:49:14 INFO 140620455696192] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fe461f8d550>
# [09/07/2021 02:49:14 INFO 140620455696192] Scaling model computed with parameters:
#  {'stdev_label':
# [0.9123467]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [1.6211948  1.043107   1.0986766  1.096235   1.1162504  0.87396395
#  0.98626137 0.8678061  0.19381995 1.1052799  1.0387332  0.60567003
#  0.9904449 ]
# <NDArray 13 @cpu(0)>, 'mean_label':
# [-0.2110377]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [ 0.23175205 -0.00030949  0.13254389  0.062962    0.15943821 -0.11837865
#   0.13413513 -0.08159901 -0.04682229  0.18030058  0.10505465  0.06168034
#   0.14785816]
# <NDArray 13 @cpu(0)>}
# [09/07/2021 02:49:14 INFO 140620455696192] nvidia-smi: took 0.031 seconds to run.
# [09/07/2021 02:49:14 INFO 140620455696192] nvidia-smi identified 0 GPUs.
# [09/07/2021 02:49:14 INFO 140620455696192] Number of GPUs being used: 0
# #metrics {"StartTime": 1630982954.198982, "EndTime": 1630982954.1990132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 294.0, "count": 1, "min": 294, "max": 294}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# #metrics {"StartTime": 1630982954.2441375, "EndTime": 1630982954.2441847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.950711669921875, "count": 1, "min": 0.950711669921875, "max": 0.950711669921875}}}
#
# #metrics {"StartTime": 1630982954.2442505, "EndTime": 1630982954.2443962, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.8414857482910156, "count": 1, "min": 0.8414857482910156, "max": 0.8414857482910156}}}
#
# #metrics {"StartTime": 1630982954.244536, "EndTime": 1630982954.2445524, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.3657061767578125, "count": 1, "min": 1.3657061767578125, "max": 1.3657061767578125}}}
#
# #metrics {"StartTime": 1630982954.2445934, "EndTime": 1630982954.2446039, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8608452606201172, "count": 1, "min": 0.8608452606201172, "max": 0.8608452606201172}}}
#
# #metrics {"StartTime": 1630982954.2446413, "EndTime": 1630982954.2446516, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.896746826171875, "count": 1, "min": 0.896746826171875, "max": 0.896746826171875}}}
#
# #metrics {"StartTime": 1630982954.2447402, "EndTime": 1630982954.2447531, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.0444219970703126, "count": 1, "min": 1.0444219970703126, "max": 1.0444219970703126}}}
#
# #metrics {"StartTime": 1630982954.2447903, "EndTime": 1630982954.2448492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 1.1287562561035156, "count": 1, "min": 1.1287562561035156, "max": 1.1287562561035156}}}
#
# #metrics {"StartTime": 1630982954.2448921, "EndTime": 1630982954.2449036, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.1508113861083984, "count": 1, "min": 1.1508113861083984, "max": 1.1508113861083984}}}
#
# #metrics {"StartTime": 1630982954.2449412, "EndTime": 1630982954.2449508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.9083158111572266, "count": 1, "min": 0.9083158111572266, "max": 0.9083158111572266}}}
#
# #metrics {"StartTime": 1630982954.245039, "EndTime": 1630982954.2450519, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.4720858764648437, "count": 1, "min": 1.4720858764648437, "max": 1.4720858764648437}}}
#
# #metrics {"StartTime": 1630982954.24509, "EndTime": 1630982954.2451003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.8205640411376953, "count": 1, "min": 0.8205640411376953, "max": 0.8205640411376953}}}
#
# #metrics {"StartTime": 1630982954.2451866, "EndTime": 1630982954.2452004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.0828132629394531, "count": 1, "min": 1.0828132629394531, "max": 1.0828132629394531}}}
#
# #metrics {"StartTime": 1630982954.2452414, "EndTime": 1630982954.2452521, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.9798310852050781, "count": 1, "min": 0.9798310852050781, "max": 0.9798310852050781}}}
#
# #metrics {"StartTime": 1630982954.2453558, "EndTime": 1630982954.2453706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 1.0623262786865235, "count": 1, "min": 1.0623262786865235, "max": 1.0623262786865235}}}
#
# #metrics {"StartTime": 1630982954.2454543, "EndTime": 1630982954.2454672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.8628333282470703, "count": 1, "min": 0.8628333282470703, "max": 0.8628333282470703}}}
#
# #metrics {"StartTime": 1630982954.245565, "EndTime": 1630982954.24558, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.056102294921875, "count": 1, "min": 1.056102294921875, "max": 1.056102294921875}}}
#
# #metrics {"StartTime": 1630982954.245658, "EndTime": 1630982954.245672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 1.0622622680664062, "count": 1, "min": 1.0622622680664062, "max": 1.0622622680664062}}}
#
# #metrics {"StartTime": 1630982954.2457135, "EndTime": 1630982954.2457585, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7815071868896485, "count": 1, "min": 0.7815071868896485, "max": 0.7815071868896485}}}
#
# #metrics {"StartTime": 1630982954.2458005, "EndTime": 1630982954.245811, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.2665275573730468, "count": 1, "min": 1.2665275573730468, "max": 1.2665275573730468}}}
#
# #metrics {"StartTime": 1630982954.2458482, "EndTime": 1630982954.2459056, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 1.0888070678710937, "count": 1, "min": 1.0888070678710937, "max": 1.0888070678710937}}}
#
# #metrics {"StartTime": 1630982954.2459497, "EndTime": 1630982954.2459612, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.7492378997802734, "count": 1, "min": 0.7492378997802734, "max": 0.7492378997802734}}}
#
# #metrics {"StartTime": 1630982954.2460468, "EndTime": 1630982954.2460608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 1.1841632080078126, "count": 1, "min": 1.1841632080078126, "max": 1.1841632080078126}}}
#
# #metrics {"StartTime": 1630982954.2461019, "EndTime": 1630982954.2461126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.7383937835693359, "count": 1, "min": 0.7383937835693359, "max": 0.7383937835693359}}}
#
# #metrics {"StartTime": 1630982954.2461967, "EndTime": 1630982954.2462087, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.8576336669921875, "count": 1, "min": 0.8576336669921875, "max": 0.8576336669921875}}}
#
# #metrics {"StartTime": 1630982954.2462876, "EndTime": 1630982954.246301, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9656539916992187, "count": 1, "min": 0.9656539916992187, "max": 0.9656539916992187}}}
#
# #metrics {"StartTime": 1630982954.2463408, "EndTime": 1630982954.2463517, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9516751861572266, "count": 1, "min": 0.9516751861572266, "max": 0.9516751861572266}}}
#
# #metrics {"StartTime": 1630982954.2464411, "EndTime": 1630982954.246454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.2638507080078125, "count": 1, "min": 1.2638507080078125, "max": 1.2638507080078125}}}
#
# #metrics {"StartTime": 1630982954.2465718, "EndTime": 1630982954.2465878, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.1539502716064454, "count": 1, "min": 1.1539502716064454, "max": 1.1539502716064454}}}
#
# #metrics {"StartTime": 1630982954.2466702, "EndTime": 1630982954.2466824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0222940063476562, "count": 1, "min": 1.0222940063476562, "max": 1.0222940063476562}}}
#
# #metrics {"StartTime": 1630982954.2467155, "EndTime": 1630982954.246724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9143247985839844, "count": 1, "min": 0.9143247985839844, "max": 0.9143247985839844}}}
#
# #metrics {"StartTime": 1630982954.24675, "EndTime": 1630982954.2467568, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.1663644409179688, "count": 1, "min": 1.1663644409179688, "max": 1.1663644409179688}}}
#
# #metrics {"StartTime": 1630982954.2467816, "EndTime": 1630982954.2467885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.1214621734619141, "count": 1, "min": 1.1214621734619141, "max": 1.1214621734619141}}}
#
# [09/07/2021 02:49:14 INFO 140620455696192] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.950711669921875
# #metrics {"StartTime": 1630982954.2966092, "EndTime": 1630982954.2966573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 1.05608336130778, "count": 1, "min": 1.05608336130778, "max": 1.05608336130778}}}
#
# #metrics {"StartTime": 1630982954.2967222, "EndTime": 1630982954.2967339, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 1.0120790004730225, "count": 1, "min": 1.0120790004730225, "max": 1.0120790004730225}}}
#
# #metrics {"StartTime": 1630982954.2967734, "EndTime": 1630982954.2967832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 1.3927216529846191, "count": 1, "min": 1.3927216529846191, "max": 1.3927216529846191}}}
#
# #metrics {"StartTime": 1630982954.2968585, "EndTime": 1630982954.2968712, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 1.017099142074585, "count": 1, "min": 1.017099142074585, "max": 1.017099142074585}}}
#
# #metrics {"StartTime": 1630982954.296906, "EndTime": 1630982954.2969928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 0.7424378395080566, "count": 1, "min": 0.7424378395080566, "max": 0.7424378395080566}}}
#
# #metrics {"StartTime": 1630982954.2970402, "EndTime": 1630982954.2970521, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 0.560845692952474, "count": 1, "min": 0.560845692952474, "max": 0.560845692952474}}}
#
# #metrics {"StartTime": 1630982954.2970877, "EndTime": 1630982954.2971804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 0.7520174980163574, "count": 1, "min": 0.7520174980163574, "max": 0.7520174980163574}}}
#
# #metrics {"StartTime": 1630982954.2972279, "EndTime": 1630982954.2972875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 0.7270233631134033, "count": 1, "min": 0.7270233631134033, "max": 0.7270233631134033}}}
#
# #metrics {"StartTime": 1630982954.2973337, "EndTime": 1630982954.2973814, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 1.1466398239135742, "count": 1, "min": 1.1466398239135742, "max": 1.1466398239135742}}}
#
# #metrics {"StartTime": 1630982954.2974274, "EndTime": 1630982954.2974389, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 1.4879275957743328, "count": 1, "min": 1.4879275957743328, "max": 1.4879275957743328}}}
#
# #metrics {"StartTime": 1630982954.297528, "EndTime": 1630982954.297541, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 1.0512981414794922, "count": 1, "min": 1.0512981414794922, "max": 1.0512981414794922}}}
#
# #metrics {"StartTime": 1630982954.2975824, "EndTime": 1630982954.2975926, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 1.2325972716013591, "count": 1, "min": 1.2325972716013591, "max": 1.2325972716013591}}}
#
# #metrics {"StartTime": 1630982954.2976744, "EndTime": 1630982954.2976868, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.7492361068725586, "count": 1, "min": 0.7492361068725586, "max": 0.7492361068725586}}}
#
# #metrics {"StartTime": 1630982954.297725, "EndTime": 1630982954.2977347, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.7629693349202474, "count": 1, "min": 0.7629693349202474, "max": 0.7629693349202474}}}
#
# #metrics {"StartTime": 1630982954.297825, "EndTime": 1630982954.2978368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.8309951623280843, "count": 1, "min": 0.8309951623280843, "max": 0.8309951623280843}}}
#
# #metrics {"StartTime": 1630982954.2979224, "EndTime": 1630982954.297936, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.630284587542216, "count": 1, "min": 0.630284587542216, "max": 0.630284587542216}}}
#
# #metrics {"StartTime": 1630982954.2979782, "EndTime": 1630982954.2979894, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 1.1851845582326253, "count": 1, "min": 1.1851845582326253, "max": 1.1851845582326253}}}
#
# #metrics {"StartTime": 1630982954.2980766, "EndTime": 1630982954.2980905, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 1.0182592074076335, "count": 1, "min": 1.0182592074076335, "max": 1.0182592074076335}}}
#
# #metrics {"StartTime": 1630982954.2981753, "EndTime": 1630982954.2981884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 1.391576608022054, "count": 1, "min": 1.391576608022054, "max": 1.391576608022054}}}
#
# #metrics {"StartTime": 1630982954.2982621, "EndTime": 1630982954.2982752, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 1.1595307191212971, "count": 1, "min": 1.1595307191212971, "max": 1.1595307191212971}}}
#
# #metrics {"StartTime": 1630982954.2983158, "EndTime": 1630982954.298363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.7783966064453125, "count": 1, "min": 0.7783966064453125, "max": 0.7783966064453125}}}
#
# #metrics {"StartTime": 1630982954.2984054, "EndTime": 1630982954.2984166, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.669192393620809, "count": 1, "min": 0.669192393620809, "max": 0.669192393620809}}}
#
# #metrics {"StartTime": 1630982954.2984545, "EndTime": 1630982954.2985125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.6563358704249064, "count": 1, "min": 0.6563358704249064, "max": 0.6563358704249064}}}
#
# #metrics {"StartTime": 1630982954.2985563, "EndTime": 1630982954.2985678, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.7098132769266764, "count": 1, "min": 0.7098132769266764, "max": 0.7098132769266764}}}
#
# #metrics {"StartTime": 1630982954.2986057, "EndTime": 1630982954.2986152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 1.1174665292104085, "count": 1, "min": 1.1174665292104085, "max": 1.1174665292104085}}}
#
# #metrics {"StartTime": 1630982954.2987053, "EndTime": 1630982954.2988958, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 1.1508281230926514, "count": 1, "min": 1.1508281230926514, "max": 1.1508281230926514}}}
#
# #metrics {"StartTime": 1630982954.29894, "EndTime": 1630982954.2989507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 1.3147001266479492, "count": 1, "min": 1.3147001266479492, "max": 1.3147001266479492}}}
#
# #metrics {"StartTime": 1630982954.2989857, "EndTime": 1630982954.2989955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 1.3043554623921711, "count": 1, "min": 1.3043554623921711, "max": 1.3043554623921711}}}
#
# #metrics {"StartTime": 1630982954.2990313, "EndTime": 1630982954.299042, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 1.068812608718872, "count": 1, "min": 1.068812608718872, "max": 1.068812608718872}}}
#
# #metrics {"StartTime": 1630982954.2991207, "EndTime": 1630982954.299134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 1.2225952943166096, "count": 1, "min": 1.2225952943166096, "max": 1.2225952943166096}}}
#
# #metrics {"StartTime": 1630982954.299173, "EndTime": 1630982954.2992306, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 0.9998846054077148, "count": 1, "min": 0.9998846054077148, "max": 0.9998846054077148}}}
#
# #metrics {"StartTime": 1630982954.2992759, "EndTime": 1630982954.299288, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 0.868851105372111, "count": 1, "min": 0.868851105372111, "max": 0.868851105372111}}}
#
# [09/07/2021 02:49:14 INFO 140620455696192] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=1.05608336130778
# [09/07/2021 02:49:14 INFO 140620455696192] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.560845692952474
# [09/07/2021 02:49:14 INFO 140620455696192] Epoch 0: Loss improved. Updating best model
# [09/07/2021 02:49:14 INFO 140620455696192] Saving model for epoch: 0
# [09/07/2021 02:49:14 INFO 140620455696192] Saved checkpoint to "/tmp/tmp1u0iwchp/mx-mod-0000.params"
# [09/07/2021 02:49:14 INFO 140620455696192] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1630982954.1992707, "EndTime": 1630982954.3085918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 488.0, "count": 1, "min": 488, "max": 488}, "Total Batches Seen": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Records Seen Between Resets": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
#
# [09/07/2021 02:49:14 INFO 140620455696192] #throughput_metric: host=algo-1, train throughput=1771.9220933068534 records/second
# #metrics {"StartTime": 1630982954.3490791, "EndTime": 1630982954.349153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.8900357818603516, "count": 1, "min": 0.8900357818603516, "max": 0.8900357818603516}}}
#
# #metrics {"StartTime": 1630982954.3492358, "EndTime": 1630982954.3492477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.7883089447021484, "count": 1, "min": 0.7883089447021484, "max": 0.7883089447021484}}}
#
# #metrics {"StartTime": 1630982954.3492866, "EndTime": 1630982954.3492959, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.2853433227539062, "count": 1, "min": 1.2853433227539062, "max": 1.2853433227539062}}}
#
# #metrics {"StartTime": 1630982954.3493288, "EndTime": 1630982954.3493364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8064373779296875, "count": 1, "min": 0.8064373779296875, "max": 0.8064373779296875}}}
#
# #metrics {"StartTime": 1630982954.3493664, "EndTime": 1630982954.3493743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.5465533828735352, "count": 1, "min": 0.5465533828735352, "max": 0.5465533828735352}}}
#
# #metrics {"StartTime": 1630982954.3494067, "EndTime": 1630982954.3494155, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.3532223892211914, "count": 1, "min": 0.3532223892211914, "max": 0.3532223892211914}}}
#
# #metrics {"StartTime": 1630982954.3494468, "EndTime": 1630982954.349454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.4450480270385742, "count": 1, "min": 0.4450480270385742, "max": 0.4450480270385742}}}
#
# #metrics {"StartTime": 1630982954.3495965, "EndTime": 1630982954.349611, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.47368152618408205, "count": 1, "min": 0.47368152618408205, "max": 0.47368152618408205}}}
#
# #metrics {"StartTime": 1630982954.3496504, "EndTime": 1630982954.3496604, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.8542903137207031, "count": 1, "min": 0.8542903137207031, "max": 0.8542903137207031}}}
#
# #metrics {"StartTime": 1630982954.3496957, "EndTime": 1630982954.3497052, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.3879588317871094, "count": 1, "min": 1.3879588317871094, "max": 1.3879588317871094}}}
#
# #metrics {"StartTime": 1630982954.3498542, "EndTime": 1630982954.3498685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.7707237243652344, "count": 1, "min": 0.7707237243652344, "max": 0.7707237243652344}}}
#
# #metrics {"StartTime": 1630982954.3499076, "EndTime": 1630982954.349918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.0179505157470703, "count": 1, "min": 1.0179505157470703, "max": 1.0179505157470703}}}
#
# #metrics {"StartTime": 1630982954.3501084, "EndTime": 1630982954.3501263, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.4537581253051758, "count": 1, "min": 0.4537581253051758, "max": 0.4537581253051758}}}
#
# #metrics {"StartTime": 1630982954.3502095, "EndTime": 1630982954.350223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.5117273330688477, "count": 1, "min": 0.5117273330688477, "max": 0.5117273330688477}}}
#
# #metrics {"StartTime": 1630982954.3502629, "EndTime": 1630982954.3502734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.5314524841308593, "count": 1, "min": 0.5314524841308593, "max": 0.5314524841308593}}}
#
# #metrics {"StartTime": 1630982954.35035, "EndTime": 1630982954.3503625, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.39173526763916017, "count": 1, "min": 0.39173526763916017, "max": 0.39173526763916017}}}
#
# #metrics {"StartTime": 1630982954.3504045, "EndTime": 1630982954.3504148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.9968754577636719, "count": 1, "min": 0.9968754577636719, "max": 0.9968754577636719}}}
#
# #metrics {"StartTime": 1630982954.3505034, "EndTime": 1630982954.3505168, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7345633697509766, "count": 1, "min": 0.7345633697509766, "max": 0.7345633697509766}}}
#
# #metrics {"StartTime": 1630982954.3505566, "EndTime": 1630982954.3505673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.1964578247070312, "count": 1, "min": 1.1964578247070312, "max": 1.1964578247070312}}}
#
# #metrics {"StartTime": 1630982954.350644, "EndTime": 1630982954.350657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 1.025803985595703, "count": 1, "min": 1.025803985595703, "max": 1.025803985595703}}}
#
# #metrics {"StartTime": 1630982954.3506958, "EndTime": 1630982954.3507597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.554821434020996, "count": 1, "min": 0.554821434020996, "max": 0.554821434020996}}}
#
# #metrics {"StartTime": 1630982954.350805, "EndTime": 1630982954.3508177, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.42866863250732423, "count": 1, "min": 0.42866863250732423, "max": 0.42866863250732423}}}
#
# #metrics {"StartTime": 1630982954.3509057, "EndTime": 1630982954.350919, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.4370318603515625, "count": 1, "min": 0.4370318603515625, "max": 0.4370318603515625}}}
#
# #metrics {"StartTime": 1630982954.3509948, "EndTime": 1630982954.3510077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.4350708770751953, "count": 1, "min": 0.4350708770751953, "max": 0.4350708770751953}}}
#
# #metrics {"StartTime": 1630982954.351082, "EndTime": 1630982954.3510947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.969595947265625, "count": 1, "min": 0.969595947265625, "max": 0.969595947265625}}}
#
# #metrics {"StartTime": 1630982954.3511705, "EndTime": 1630982954.3511837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9613291168212891, "count": 1, "min": 0.9613291168212891, "max": 0.9613291168212891}}}
#
# #metrics {"StartTime": 1630982954.3512251, "EndTime": 1630982954.3512356, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.2184191131591797, "count": 1, "min": 1.2184191131591797, "max": 1.2184191131591797}}}
#
# #metrics {"StartTime": 1630982954.3513207, "EndTime": 1630982954.3513331, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.1237201690673828, "count": 1, "min": 1.1237201690673828, "max": 1.1237201690673828}}}
#
# #metrics {"StartTime": 1630982954.351375, "EndTime": 1630982954.351421, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0198078918457032, "count": 1, "min": 1.0198078918457032, "max": 1.0198078918457032}}}
#
# #metrics {"StartTime": 1630982954.3514643, "EndTime": 1630982954.351476, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.272796630859375, "count": 1, "min": 1.272796630859375, "max": 1.272796630859375}}}
#
# #metrics {"StartTime": 1630982954.3515139, "EndTime": 1630982954.3515701, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.7945167541503906, "count": 1, "min": 0.7945167541503906, "max": 0.7945167541503906}}}
#
# #metrics {"StartTime": 1630982954.3516147, "EndTime": 1630982954.3516264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.6497319030761719, "count": 1, "min": 0.6497319030761719, "max": 0.6497319030761719}}}
#
# [09/07/2021 02:49:14 INFO 140620455696192] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.8900357818603516
# #metrics {"StartTime": 1630982954.4093368, "EndTime": 1630982954.4093878, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 1.0271474520365398, "count": 1, "min": 1.0271474520365398, "max": 1.0271474520365398}}}
#
# #metrics {"StartTime": 1630982954.4094532, "EndTime": 1630982954.4094658, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 0.9869062900543213, "count": 1, "min": 0.9869062900543213, "max": 0.9869062900543213}}}
#
# #metrics {"StartTime": 1630982954.4095042, "EndTime": 1630982954.4095283, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 1.3507668177286785, "count": 1, "min": 1.3507668177286785, "max": 1.3507668177286785}}}
#
# #metrics {"StartTime": 1630982954.4095657, "EndTime": 1630982954.4095745, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 0.990259567896525, "count": 1, "min": 0.990259567896525, "max": 0.990259567896525}}}
#
# #metrics {"StartTime": 1630982954.4096034, "EndTime": 1630982954.4096115, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 1.289949893951416, "count": 1, "min": 1.289949893951416, "max": 1.289949893951416}}}
#
# #metrics {"StartTime": 1630982954.4096954, "EndTime": 1630982954.4097068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 1.307513952255249, "count": 1, "min": 1.307513952255249, "max": 1.307513952255249}}}
#
# #metrics {"StartTime": 1630982954.4098291, "EndTime": 1630982954.4098418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 1.4671532313028972, "count": 1, "min": 1.4671532313028972, "max": 1.4671532313028972}}}
#
# #metrics {"StartTime": 1630982954.4098806, "EndTime": 1630982954.4098907, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 1.4194467862447102, "count": 1, "min": 1.4194467862447102, "max": 1.4194467862447102}}}
#
# #metrics {"StartTime": 1630982954.4099257, "EndTime": 1630982954.4099355, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 1.1221850713094075, "count": 1, "min": 1.1221850713094075, "max": 1.1221850713094075}}}
#
# #metrics {"StartTime": 1630982954.409969, "EndTime": 1630982954.4099784, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 1.4429965019226074, "count": 1, "min": 1.4429965019226074, "max": 1.4429965019226074}}}
#
# #metrics {"StartTime": 1630982954.410106, "EndTime": 1630982954.4101186, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 1.0281309286753337, "count": 1, "min": 1.0281309286753337, "max": 1.0281309286753337}}}
#
# #metrics {"StartTime": 1630982954.4101555, "EndTime": 1630982954.4101648, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 1.2000854810078938, "count": 1, "min": 1.2000854810078938, "max": 1.2000854810078938}}}
#
# #metrics {"StartTime": 1630982954.4102829, "EndTime": 1630982954.4103518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 1.4097426732381184, "count": 1, "min": 1.4097426732381184, "max": 1.4097426732381184}}}
#
# #metrics {"StartTime": 1630982954.4104338, "EndTime": 1630982954.4104483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 1.4188989003499348, "count": 1, "min": 1.4188989003499348, "max": 1.4188989003499348}}}
#
# #metrics {"StartTime": 1630982954.410526, "EndTime": 1630982954.4105403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 1.3776183128356934, "count": 1, "min": 1.3776183128356934, "max": 1.3776183128356934}}}
#
# #metrics {"StartTime": 1630982954.4106011, "EndTime": 1630982954.4106133, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 1.359721024831136, "count": 1, "min": 1.359721024831136, "max": 1.359721024831136}}}
#
# #metrics {"StartTime": 1630982954.4106483, "EndTime": 1630982954.4106588, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 1.1525992552439372, "count": 1, "min": 1.1525992552439372, "max": 1.1525992552439372}}}
#
# #metrics {"StartTime": 1630982954.410693, "EndTime": 1630982954.4107013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.9994086424509684, "count": 1, "min": 0.9994086424509684, "max": 0.9994086424509684}}}
#
# #metrics {"StartTime": 1630982954.4107363, "EndTime": 1630982954.410746, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 1.3556283315022786, "count": 1, "min": 1.3556283315022786, "max": 1.3556283315022786}}}
#
# #metrics {"StartTime": 1630982954.4107816, "EndTime": 1630982954.4107919, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 1.1288548310597737, "count": 1, "min": 1.1288548310597737, "max": 1.1288548310597737}}}
#
# #metrics {"StartTime": 1630982954.4108276, "EndTime": 1630982954.4109187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 1.21407151222229, "count": 1, "min": 1.21407151222229, "max": 1.21407151222229}}}
#
# #metrics {"StartTime": 1630982954.4109643, "EndTime": 1630982954.4109755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 1.3254947662353516, "count": 1, "min": 1.3254947662353516, "max": 1.3254947662353516}}}
#
# #metrics {"StartTime": 1630982954.4110122, "EndTime": 1630982954.4110992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 1.2018145720163982, "count": 1, "min": 1.2018145720163982, "max": 1.2018145720163982}}}
#
# #metrics {"StartTime": 1630982954.4112134, "EndTime": 1630982954.4112291, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 1.2412665685017903, "count": 1, "min": 1.2412665685017903, "max": 1.2412665685017903}}}
#
# #metrics {"StartTime": 1630982954.4112735, "EndTime": 1630982954.4113271, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 1.1268339157104492, "count": 1, "min": 1.1268339157104492, "max": 1.1268339157104492}}}
#
# #metrics {"StartTime": 1630982954.4113727, "EndTime": 1630982954.4113839, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 1.1702931722005208, "count": 1, "min": 1.1702931722005208, "max": 1.1702931722005208}}}
#
# #metrics {"StartTime": 1630982954.4114614, "EndTime": 1630982954.4114735, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 1.296300967534383, "count": 1, "min": 1.296300967534383, "max": 1.296300967534383}}}
#
# #metrics {"StartTime": 1630982954.4116313, "EndTime": 1630982954.411649, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 1.3109735647837322, "count": 1, "min": 1.3109735647837322, "max": 1.3109735647837322}}}
#
# #metrics {"StartTime": 1630982954.4116948, "EndTime": 1630982954.4117064, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 1.7273066838582356, "count": 1, "min": 1.7273066838582356, "max": 1.7273066838582356}}}
#
# #metrics {"StartTime": 1630982954.4117782, "EndTime": 1630982954.4117904, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 1.7701838811238606, "count": 1, "min": 1.7701838811238606, "max": 1.7701838811238606}}}
#
# ...
#
# #metrics {"StartTime": 1630982955.871669, "EndTime": 1630982955.8716896, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.062867202758789, "count": 1, "min": 1.062867202758789, "max": 1.062867202758789}}}
#
# #metrics {"StartTime": 1630982955.871956, "EndTime": 1630982955.8719773, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9486235046386718, "count": 1, "min": 0.9486235046386718, "max": 0.9486235046386718}}}
#
# #metrics {"StartTime": 1630982955.872243, "EndTime": 1630982955.872264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.1451493835449218, "count": 1, "min": 1.1451493835449218, "max": 1.1451493835449218}}}
#
# #metrics {"StartTime": 1630982955.8725371, "EndTime": 1630982955.8725576, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.1511328887939454, "count": 1, "min": 1.1511328887939454, "max": 1.1511328887939454}}}
#
# [09/07/2021 02:49:15 INFO 140620455696192] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.43258071899414063
# #metrics {"StartTime": 1630982955.931702, "EndTime": 1630982955.9317799, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 0.6774826844533285, "count": 1, "min": 0.6774826844533285, "max": 0.6774826844533285}}}
#
# #metrics {"StartTime": 1630982955.9323046, "EndTime": 1630982955.9323313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 0.6807112693786621, "count": 1, "min": 0.6807112693786621, "max": 0.6807112693786621}}}
#
# #metrics {"StartTime": 1630982955.932629, "EndTime": 1630982955.9326494, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 0.8238527774810791, "count": 1, "min": 0.8238527774810791, "max": 0.8238527774810791}}}
#
# #metrics {"StartTime": 1630982955.9329178, "EndTime": 1630982955.932938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 0.6803070704142252, "count": 1, "min": 0.6803070704142252, "max": 0.6803070704142252}}}
#
# #metrics {"StartTime": 1630982955.933208, "EndTime": 1630982955.9332292, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 0.4574044545491536, "count": 1, "min": 0.4574044545491536, "max": 0.4574044545491536}}}
#
# #metrics {"StartTime": 1630982955.9335089, "EndTime": 1630982955.9335535, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 0.49996598561604816, "count": 1, "min": 0.49996598561604816, "max": 0.49996598561604816}}}
#
# #metrics {"StartTime": 1630982955.9338472, "EndTime": 1630982955.9338715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 0.5163917541503906, "count": 1, "min": 0.5163917541503906, "max": 0.5163917541503906}}}
#
# #metrics {"StartTime": 1630982955.934162, "EndTime": 1630982955.934183, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 0.518569270769755, "count": 1, "min": 0.518569270769755, "max": 0.518569270769755}}}
#
# #metrics {"StartTime": 1630982955.9344532, "EndTime": 1630982955.9344738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 0.8061532179514567, "count": 1, "min": 0.8061532179514567, "max": 0.8061532179514567}}}
#
# #metrics {"StartTime": 1630982955.9347417, "EndTime": 1630982955.934762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 0.8760004838307699, "count": 1, "min": 0.8760004838307699, "max": 0.8760004838307699}}}
#
# #metrics {"StartTime": 1630982955.935031, "EndTime": 1630982955.9350507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 0.7383246421813965, "count": 1, "min": 0.7383246421813965, "max": 0.7383246421813965}}}
#
# #metrics {"StartTime": 1630982955.935315, "EndTime": 1630982955.9353347, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 0.798662265141805, "count": 1, "min": 0.798662265141805, "max": 0.798662265141805}}}
#
# #metrics {"StartTime": 1630982955.9355893, "EndTime": 1630982955.9356096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.4578196207682292, "count": 1, "min": 0.4578196207682292, "max": 0.4578196207682292}}}
#
# #metrics {"StartTime": 1630982955.9358766, "EndTime": 1630982955.9358976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.46722503503163654, "count": 1, "min": 0.46722503503163654, "max": 0.46722503503163654}}}
#
# #metrics {"StartTime": 1630982955.93618, "EndTime": 1630982955.9362009, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.4838241736094157, "count": 1, "min": 0.4838241736094157, "max": 0.4838241736094157}}}
#
# #metrics {"StartTime": 1630982955.9364717, "EndTime": 1630982955.9364924, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.5058112541834513, "count": 1, "min": 0.5058112541834513, "max": 0.5058112541834513}}}
#
# #metrics {"StartTime": 1630982955.9367673, "EndTime": 1630982955.936788, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 0.7590286731719971, "count": 1, "min": 0.7590286731719971, "max": 0.7590286731719971}}}
#
# #metrics {"StartTime": 1630982955.9370668, "EndTime": 1630982955.9370875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.7145383358001709, "count": 1, "min": 0.7145383358001709, "max": 0.7145383358001709}}}
#
# #metrics {"StartTime": 1630982955.9373531, "EndTime": 1630982955.937373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 0.9076029459635416, "count": 1, "min": 0.9076029459635416, "max": 0.9076029459635416}}}
#
# #metrics {"StartTime": 1630982955.937672, "EndTime": 1630982955.9376922, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 0.7586540381113688, "count": 1, "min": 0.7586540381113688, "max": 0.7586540381113688}}}
#
# #metrics {"StartTime": 1630982955.9379733, "EndTime": 1630982955.9379942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.5701437393824259, "count": 1, "min": 0.5701437393824259, "max": 0.5701437393824259}}}
#
# #metrics {"StartTime": 1630982955.9382699, "EndTime": 1630982955.9382896, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.4661986033121745, "count": 1, "min": 0.4661986033121745, "max": 0.4661986033121745}}}
#
# #metrics {"StartTime": 1630982955.938563, "EndTime": 1630982955.9385843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.5680944522221884, "count": 1, "min": 0.5680944522221884, "max": 0.5680944522221884}}}
#
# #metrics {"StartTime": 1630982955.9388516, "EndTime": 1630982955.9388723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.5475363731384277, "count": 1, "min": 0.5475363731384277, "max": 0.5475363731384277}}}
#
# #metrics {"StartTime": 1630982955.9391654, "EndTime": 1630982955.939186, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 1.1521388689676921, "count": 1, "min": 1.1521388689676921, "max": 1.1521388689676921}}}
#
# #metrics {"StartTime": 1630982955.9394565, "EndTime": 1630982955.9394774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 1.1101908683776855, "count": 1, "min": 1.1101908683776855, "max": 1.1101908683776855}}}
#
# #metrics {"StartTime": 1630982955.939779, "EndTime": 1630982955.9397998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 1.080248196919759, "count": 1, "min": 1.080248196919759, "max": 1.080248196919759}}}
#
# #metrics {"StartTime": 1630982955.9400668, "EndTime": 1630982955.9400866, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 1.108044147491455, "count": 1, "min": 1.108044147491455, "max": 1.108044147491455}}}
#
# #metrics {"StartTime": 1630982955.940342, "EndTime": 1630982955.940362, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 1.1432851950327556, "count": 1, "min": 1.1432851950327556, "max": 1.1432851950327556}}}
#
# #metrics {"StartTime": 1630982955.9406393, "EndTime": 1630982955.9406607, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 1.112316608428955, "count": 1, "min": 1.112316608428955, "max": 1.112316608428955}}}
#
# #metrics {"StartTime": 1630982955.9409406, "EndTime": 1630982955.940962, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 1.1728923320770264, "count": 1, "min": 1.1728923320770264, "max": 1.1728923320770264}}}
#
# #metrics {"StartTime": 1630982955.9412425, "EndTime": 1630982955.941264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 1.158691167831421, "count": 1, "min": 1.158691167831421, "max": 1.158691167831421}}}
#
# [09/07/2021 02:49:15 INFO 140620455696192] #quality_metric: host=algo-1, epoch=14, validation mse_objective <loss>=0.6774826844533285
# [09/07/2021 02:49:15 INFO 140620455696192] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.4574044545491536
# [09/07/2021 02:49:15 INFO 140620455696192] Saving model for epoch: 14
# [09/07/2021 02:49:15 INFO 140620455696192] Saved checkpoint to "/tmp/tmpc4o4play/mx-mod-0000.params"
# [09/07/2021 02:49:15 INFO 140620455696192] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1630982955.8091033, "EndTime": 1630982955.9492178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3204.0, "count": 1, "min": 3204, "max": 3204}, "Total Batches Seen": {"sum": 33.0, "count": 1, "min": 33, "max": 33}, "Max Records Seen Between Resets": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
#
# [09/07/2021 02:49:15 INFO 140620455696192] #throughput_metric: host=algo-1, train throughput=1380.9111252535024 records/second
# [09/07/2021 02:49:15 WARNING 140620455696192] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/07/2021 02:49:15 WARNING 140620455696192] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/07/2021 02:49:15 INFO 140620455696192] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.4574044545491536
# [09/07/2021 02:49:16 INFO 140620455696192] #validation_score (algo-1) : ('mse_objective', 0.3980878988901774)
# [09/07/2021 02:49:16 INFO 140620455696192] #validation_score (algo-1) : ('mse', 0.3980878988901774)
# [09/07/2021 02:49:16 INFO 140620455696192] #validation_score (algo-1) : ('absolute_loss', 0.40454145272572833)
# [09/07/2021 02:49:16 INFO 140620455696192] #quality_metric: host=algo-1, validation mse_objective <loss>=0.3980878988901774
# [09/07/2021 02:49:16 INFO 140620455696192] #quality_metric: host=algo-1, validation mse <loss>=0.3980878988901774
# [09/07/2021 02:49:16 INFO 140620455696192] #quality_metric: host=algo-1, validation absolute_loss <loss>=0.40454145272572833
# [09/07/2021 02:49:16 INFO 140620455696192] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 1, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [09/07/2021 02:49:16 INFO 140620455696192] Saved checkpoint to "/tmp/tmpw0axi94u/mx-mod-0000.params"
# [09/07/2021 02:49:16 INFO 140620455696192] Test data is not provided.
# #metrics {"StartTime": 1630982954.0534205, "EndTime": 1630982956.0198717, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 145.21288871765137, "count": 1, "min": 145.21288871765137, "max": 145.21288871765137}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 10.22648811340332, "count": 16, "min": 0.2071857452392578, "max": 1.4412403106689453}, "update.time": {"sum": 1693.3507919311523, "count": 15, "min": 88.37771415710449, "max": 176.27310752868652}, "finalize.time": {"sum": 63.07792663574219, "count": 1, "min": 63.07792663574219, "max": 63.07792663574219}, "setuptime": {"sum": 32.202959060668945, "count": 1, "min": 32.202959060668945, "max": 32.202959060668945}, "totaltime": {"sum": 2173.1719970703125, "count": 1, "min": 2173.1719970703125, "max": 2173.1719970703125}}}
#
#
# 2021-09-07 02:49:31 Uploading - Uploading generated training model
# 2021-09-07 02:49:31 Completed - Training job completed
# Training seconds: 66
# Billable seconds: 66

# %% [markdown]
# ## Download the model

# %%
sagemaker.s3.S3Downloader.download(s3_uri=model.model_data, local_path="./")
