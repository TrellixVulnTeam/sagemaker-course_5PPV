# %% [markdown]
# # Deploy and Validate the Linear Learner

# %%
import os
import time
import boto3
import sagemaker
import pandas as pd
## SageMaker dependencies
import sagemaker
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.image_uris import retrieve

## This instantiates a SageMaker session that we will be operating in.
session = sagemaker.Session()
role = sagemaker.get_execution_role()

# %% [markdown]
# At first we will do the same as before, this will simulate a scenario where we will test the model just trained on SageMaker.
#
# If you are curious how to deploy from an already trained job, we will do that on the next lab.

# %%
# %store -r X_train
# %store -r X_test
# %store -r X_val
# %store -r Y_train
# %store -r Y_test
# %store -r Y_val

# %%
data_dir = "data/"
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

prefix = "boston-dataset"
pd.concat([Y_train, X_train], axis=1).to_csv(
    os.path.join(data_dir, "train.csv"), header=False, index=False
)
pd.concat([Y_val, X_val], axis=1).to_csv(
    os.path.join(data_dir, "validation.csv"), header=False, index=False
)

val_location = session.upload_data(os.path.join(data_dir, "validation.csv"), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, "train.csv"), key_prefix=prefix)

# %%
s3_input_train = TrainingInput(s3_data=train_location, content_type="text/csv")
s3_input_validation = TrainingInput(s3_data=val_location, content_type="text/csv")

# %%
container = retrieve(framework='linear-learner', region=session.boto_region_name, version="latest")

model = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m5.large",
    output_path="s3://{}/{}/output".format(session.default_bucket(), prefix),
    sagemaker_session=session,
)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.

# %%
model.set_hyperparameters(
    feature_dim=X_train.shape[1], predictor_type="regressor", mini_batch_size=100
)

# %%
model.fit({"train": s3_input_train, "validation": s3_input_validation}, wait=True)
# Out:
# 2021-09-07 11:19:04 Starting - Starting the training job...
# 2021-09-07 11:19:30 Starting - Launching requested ML instancesProfilerReport-1631013544: InProgress
# ......
# 2021-09-07 11:20:30 Starting - Preparing the instances for training............
# 2021-09-07 11:22:30 Downloading - Downloading input data...
# 2021-09-07 11:23:00 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/07/2021 11:23:05 INFO 140674731267904] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [09/07/2021 11:23:05 INFO 140674731267904] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '13', 'predictor_type': 'regressor', 'mini_batch_size': '100'}
# [09/07/2021 11:23:05 INFO 140674731267904] Final configuration: {'mini_batch_size': '100', 'epochs': '15', 'feature_dim': '13', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [09/07/2021 11:23:05 WARNING 140674731267904] Loggers have already been setup.
# Process 1 is a worker.
# [09/07/2021 11:23:05 INFO 140674731267904] Using default worker.
# [09/07/2021 11:23:05 INFO 140674731267904] Checkpoint loading and saving are disabled.
# [09/07/2021 11:23:05 INFO 140674731267904] Create Store: local
# [09/07/2021 11:23:05 INFO 140674731267904] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7ff114476050>
# [09/07/2021 11:23:05 INFO 140674731267904] Scaling model computed with parameters:
#  {'stdev_label':
# [0.9123467]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [1.6211948  1.043107   1.0986766  1.096235   1.1162504  0.87396395
#  0.98626137 0.8678061  0.19381995 1.1052799  1.0387332  0.60567003
#  0.9904449 ]
# <NDArray 13 @cpu(0)>, 'mean_label':
# [-0.2110377]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [ 0.23175205 -0.00030949  0.13254389  0.062962    0.15943821 -0.11837865
#   0.13413513 -0.08159901 -0.04682229  0.18030058  0.10505465  0.06168034
#   0.14785816]
# <NDArray 13 @cpu(0)>}
# [09/07/2021 11:23:05 INFO 140674731267904] nvidia-smi: took 0.031 seconds to run.
# [09/07/2021 11:23:05 INFO 140674731267904] nvidia-smi identified 0 GPUs.
# [09/07/2021 11:23:05 INFO 140674731267904] Number of GPUs being used: 0
# #metrics {"StartTime": 1631013785.6136804, "EndTime": 1631013785.6137292, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 294.0, "count": 1, "min": 294, "max": 294}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# #metrics {"StartTime": 1631013785.654892, "EndTime": 1631013785.6549482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.950711669921875, "count": 1, "min": 0.950711669921875, "max": 0.950711669921875}}}
#
# #metrics {"StartTime": 1631013785.6550186, "EndTime": 1631013785.6550312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.8414857482910156, "count": 1, "min": 0.8414857482910156, "max": 0.8414857482910156}}}
#
# #metrics {"StartTime": 1631013785.6550725, "EndTime": 1631013785.6550817, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.3657061767578125, "count": 1, "min": 1.3657061767578125, "max": 1.3657061767578125}}}
#
# #metrics {"StartTime": 1631013785.6551557, "EndTime": 1631013785.6551857, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8608452606201172, "count": 1, "min": 0.8608452606201172, "max": 0.8608452606201172}}}
#
# #metrics {"StartTime": 1631013785.6552258, "EndTime": 1631013785.6552355, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.896746826171875, "count": 1, "min": 0.896746826171875, "max": 0.896746826171875}}}
#
# #metrics {"StartTime": 1631013785.6552947, "EndTime": 1631013785.6553054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.0444219970703126, "count": 1, "min": 1.0444219970703126, "max": 1.0444219970703126}}}
#
# #metrics {"StartTime": 1631013785.6553385, "EndTime": 1631013785.6553473, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 1.1287562561035156, "count": 1, "min": 1.1287562561035156, "max": 1.1287562561035156}}}
#
# #metrics {"StartTime": 1631013785.65538, "EndTime": 1631013785.655389, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.1508113861083984, "count": 1, "min": 1.1508113861083984, "max": 1.1508113861083984}}}
#
# #metrics {"StartTime": 1631013785.6556504, "EndTime": 1631013785.6556885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.9083158111572266, "count": 1, "min": 0.9083158111572266, "max": 0.9083158111572266}}}
#
# #metrics {"StartTime": 1631013785.6557589, "EndTime": 1631013785.6557906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.4720858764648437, "count": 1, "min": 1.4720858764648437, "max": 1.4720858764648437}}}
#
# #metrics {"StartTime": 1631013785.6559105, "EndTime": 1631013785.6559262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.8205640411376953, "count": 1, "min": 0.8205640411376953, "max": 0.8205640411376953}}}
#
# #metrics {"StartTime": 1631013785.656081, "EndTime": 1631013785.6560977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.0828132629394531, "count": 1, "min": 1.0828132629394531, "max": 1.0828132629394531}}}
#
# #metrics {"StartTime": 1631013785.6561584, "EndTime": 1631013785.6561723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.9798310852050781, "count": 1, "min": 0.9798310852050781, "max": 0.9798310852050781}}}
#
# #metrics {"StartTime": 1631013785.6562386, "EndTime": 1631013785.6562514, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 1.0623262786865235, "count": 1, "min": 1.0623262786865235, "max": 1.0623262786865235}}}
#
# #metrics {"StartTime": 1631013785.6562934, "EndTime": 1631013785.6563044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.8628333282470703, "count": 1, "min": 0.8628333282470703, "max": 0.8628333282470703}}}
#
# #metrics {"StartTime": 1631013785.656361, "EndTime": 1631013785.6563733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.056102294921875, "count": 1, "min": 1.056102294921875, "max": 1.056102294921875}}}
#
# #metrics {"StartTime": 1631013785.656439, "EndTime": 1631013785.656451, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 1.0622622680664062, "count": 1, "min": 1.0622622680664062, "max": 1.0622622680664062}}}
#
# #metrics {"StartTime": 1631013785.6565137, "EndTime": 1631013785.656526, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7815071868896485, "count": 1, "min": 0.7815071868896485, "max": 0.7815071868896485}}}
#
# #metrics {"StartTime": 1631013785.656566, "EndTime": 1631013785.656577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.2665275573730468, "count": 1, "min": 1.2665275573730468, "max": 1.2665275573730468}}}
#
# #metrics {"StartTime": 1631013785.656633, "EndTime": 1631013785.6566455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 1.0888070678710937, "count": 1, "min": 1.0888070678710937, "max": 1.0888070678710937}}}
#
# #metrics {"StartTime": 1631013785.6567097, "EndTime": 1631013785.6567216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.7492378997802734, "count": 1, "min": 0.7492378997802734, "max": 0.7492378997802734}}}
#
# #metrics {"StartTime": 1631013785.6567838, "EndTime": 1631013785.656796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 1.1841632080078126, "count": 1, "min": 1.1841632080078126, "max": 1.1841632080078126}}}
#
# #metrics {"StartTime": 1631013785.656836, "EndTime": 1631013785.6568458, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.7383937835693359, "count": 1, "min": 0.7383937835693359, "max": 0.7383937835693359}}}
#
# #metrics {"StartTime": 1631013785.6568794, "EndTime": 1631013785.65689, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.8576336669921875, "count": 1, "min": 0.8576336669921875, "max": 0.8576336669921875}}}
#
# #metrics {"StartTime": 1631013785.656945, "EndTime": 1631013785.6569574, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9656539916992187, "count": 1, "min": 0.9656539916992187, "max": 0.9656539916992187}}}
#
# #metrics {"StartTime": 1631013785.6570227, "EndTime": 1631013785.6570354, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9516751861572266, "count": 1, "min": 0.9516751861572266, "max": 0.9516751861572266}}}
#
# #metrics {"StartTime": 1631013785.657099, "EndTime": 1631013785.6571116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.2638507080078125, "count": 1, "min": 1.2638507080078125, "max": 1.2638507080078125}}}
#
# #metrics {"StartTime": 1631013785.6571515, "EndTime": 1631013785.6571624, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.1539502716064454, "count": 1, "min": 1.1539502716064454, "max": 1.1539502716064454}}}
#
# #metrics {"StartTime": 1631013785.657199, "EndTime": 1631013785.6572092, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0222940063476562, "count": 1, "min": 1.0222940063476562, "max": 1.0222940063476562}}}
#
# #metrics {"StartTime": 1631013785.6572456, "EndTime": 1631013785.6572552, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9143247985839844, "count": 1, "min": 0.9143247985839844, "max": 0.9143247985839844}}}
#
# #metrics {"StartTime": 1631013785.6573102, "EndTime": 1631013785.6573226, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.1663644409179688, "count": 1, "min": 1.1663644409179688, "max": 1.1663644409179688}}}
#
# #metrics {"StartTime": 1631013785.6573875, "EndTime": 1631013785.6574004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.1214621734619141, "count": 1, "min": 1.1214621734619141, "max": 1.1214621734619141}}}
#
# [09/07/2021 11:23:05 INFO 140674731267904] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.950711669921875
# #metrics {"StartTime": 1631013785.6986074, "EndTime": 1631013785.698661, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 1.05608336130778, "count": 1, "min": 1.05608336130778, "max": 1.05608336130778}}}
#
# #metrics {"StartTime": 1631013785.6987326, "EndTime": 1631013785.6987467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 1.0120790004730225, "count": 1, "min": 1.0120790004730225, "max": 1.0120790004730225}}}
#
# #metrics {"StartTime": 1631013785.6987882, "EndTime": 1631013785.698797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 1.3927216529846191, "count": 1, "min": 1.3927216529846191, "max": 1.3927216529846191}}}
#
# #metrics {"StartTime": 1631013785.6988587, "EndTime": 1631013785.698869, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 1.017099142074585, "count": 1, "min": 1.017099142074585, "max": 1.017099142074585}}}
#
# #metrics {"StartTime": 1631013785.698926, "EndTime": 1631013785.6989374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 0.7424378395080566, "count": 1, "min": 0.7424378395080566, "max": 0.7424378395080566}}}
#
# #metrics {"StartTime": 1631013785.6989942, "EndTime": 1631013785.6990051, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 0.560845692952474, "count": 1, "min": 0.560845692952474, "max": 0.560845692952474}}}
#
# #metrics {"StartTime": 1631013785.6990397, "EndTime": 1631013785.6990485, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 0.7520174980163574, "count": 1, "min": 0.7520174980163574, "max": 0.7520174980163574}}}
#
# #metrics {"StartTime": 1631013785.699082, "EndTime": 1631013785.6990921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 0.7270233631134033, "count": 1, "min": 0.7270233631134033, "max": 0.7270233631134033}}}
#
# #metrics {"StartTime": 1631013785.6991446, "EndTime": 1631013785.6991568, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 1.1466398239135742, "count": 1, "min": 1.1466398239135742, "max": 1.1466398239135742}}}
#
# #metrics {"StartTime": 1631013785.6992226, "EndTime": 1631013785.6992345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 1.4879275957743328, "count": 1, "min": 1.4879275957743328, "max": 1.4879275957743328}}}
#
# #metrics {"StartTime": 1631013785.6992984, "EndTime": 1631013785.69931, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 1.0512981414794922, "count": 1, "min": 1.0512981414794922, "max": 1.0512981414794922}}}
#
# #metrics {"StartTime": 1631013785.69937, "EndTime": 1631013785.6993809, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 1.2325972716013591, "count": 1, "min": 1.2325972716013591, "max": 1.2325972716013591}}}
#
# #metrics {"StartTime": 1631013785.6994185, "EndTime": 1631013785.6994286, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.7492361068725586, "count": 1, "min": 0.7492361068725586, "max": 0.7492361068725586}}}
#
# #metrics {"StartTime": 1631013785.699464, "EndTime": 1631013785.6994734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.7629693349202474, "count": 1, "min": 0.7629693349202474, "max": 0.7629693349202474}}}
#
# #metrics {"StartTime": 1631013785.699526, "EndTime": 1631013785.6995378, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.8309951623280843, "count": 1, "min": 0.8309951623280843, "max": 0.8309951623280843}}}
#
# #metrics {"StartTime": 1631013785.6995995, "EndTime": 1631013785.6996126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.630284587542216, "count": 1, "min": 0.630284587542216, "max": 0.630284587542216}}}
#
# #metrics {"StartTime": 1631013785.6996725, "EndTime": 1631013785.6996856, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 1.1851845582326253, "count": 1, "min": 1.1851845582326253, "max": 1.1851845582326253}}}
#
# #metrics {"StartTime": 1631013785.6997259, "EndTime": 1631013785.6997557, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 1.0182592074076335, "count": 1, "min": 1.0182592074076335, "max": 1.0182592074076335}}}
#
# #metrics {"StartTime": 1631013785.6997979, "EndTime": 1631013785.6998088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 1.391576608022054, "count": 1, "min": 1.391576608022054, "max": 1.391576608022054}}}
#
# #metrics {"StartTime": 1631013785.699847, "EndTime": 1631013785.6998558, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 1.1595307191212971, "count": 1, "min": 1.1595307191212971, "max": 1.1595307191212971}}}
#
# #metrics {"StartTime": 1631013785.6999075, "EndTime": 1631013785.69992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.7783966064453125, "count": 1, "min": 0.7783966064453125, "max": 0.7783966064453125}}}
#
# #metrics {"StartTime": 1631013785.699981, "EndTime": 1631013785.699995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.669192393620809, "count": 1, "min": 0.669192393620809, "max": 0.669192393620809}}}
#
# #metrics {"StartTime": 1631013785.7000384, "EndTime": 1631013785.7000701, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.6563358704249064, "count": 1, "min": 0.6563358704249064, "max": 0.6563358704249064}}}
#
# #metrics {"StartTime": 1631013785.7001116, "EndTime": 1631013785.7001398, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.7098132769266764, "count": 1, "min": 0.7098132769266764, "max": 0.7098132769266764}}}
#
# #metrics {"StartTime": 1631013785.7001834, "EndTime": 1631013785.7001953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 1.1174665292104085, "count": 1, "min": 1.1174665292104085, "max": 1.1174665292104085}}}
#
# #metrics {"StartTime": 1631013785.700234, "EndTime": 1631013785.7002435, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 1.1508281230926514, "count": 1, "min": 1.1508281230926514, "max": 1.1508281230926514}}}
#
# #metrics {"StartTime": 1631013785.7002807, "EndTime": 1631013785.7002912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 1.3147001266479492, "count": 1, "min": 1.3147001266479492, "max": 1.3147001266479492}}}
#
# #metrics {"StartTime": 1631013785.7003438, "EndTime": 1631013785.700356, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 1.3043554623921711, "count": 1, "min": 1.3043554623921711, "max": 1.3043554623921711}}}
#
# #metrics {"StartTime": 1631013785.7004216, "EndTime": 1631013785.7004342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 1.068812608718872, "count": 1, "min": 1.068812608718872, "max": 1.068812608718872}}}
#
# #metrics {"StartTime": 1631013785.7004974, "EndTime": 1631013785.7005088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 1.2225952943166096, "count": 1, "min": 1.2225952943166096, "max": 1.2225952943166096}}}
#
# #metrics {"StartTime": 1631013785.7005706, "EndTime": 1631013785.7005832, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 0.9998846054077148, "count": 1, "min": 0.9998846054077148, "max": 0.9998846054077148}}}
#
# #metrics {"StartTime": 1631013785.7006218, "EndTime": 1631013785.7006328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 0.868851105372111, "count": 1, "min": 0.868851105372111, "max": 0.868851105372111}}}
#
# [09/07/2021 11:23:05 INFO 140674731267904] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=1.05608336130778
# [09/07/2021 11:23:05 INFO 140674731267904] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.560845692952474
# [09/07/2021 11:23:05 INFO 140674731267904] Epoch 0: Loss improved. Updating best model
# [09/07/2021 11:23:05 INFO 140674731267904] Saving model for epoch: 0
# [09/07/2021 11:23:05 INFO 140674731267904] Saved checkpoint to "/tmp/tmpaorqz3r9/mx-mod-0000.params"
# [09/07/2021 11:23:05 INFO 140674731267904] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1631013785.6141453, "EndTime": 1631013785.710125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 488.0, "count": 1, "min": 488, "max": 488}, "Total Batches Seen": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Records Seen Between Resets": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
#
# [09/07/2021 11:23:05 INFO 140674731267904] #throughput_metric: host=algo-1, train throughput=2018.3830412112854 records/second
# #metrics {"StartTime": 1631013785.7477174, "EndTime": 1631013785.7478015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.8900357818603516, "count": 1, "min": 0.8900357818603516, "max": 0.8900357818603516}}}
#
# #metrics {"StartTime": 1631013785.7478945, "EndTime": 1631013785.747908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.7883089447021484, "count": 1, "min": 0.7883089447021484, "max": 0.7883089447021484}}}
#
# #metrics {"StartTime": 1631013785.7479486, "EndTime": 1631013785.747958, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.2853433227539062, "count": 1, "min": 1.2853433227539062, "max": 1.2853433227539062}}}
#
# #metrics {"StartTime": 1631013785.7480192, "EndTime": 1631013785.7480297, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8064373779296875, "count": 1, "min": 0.8064373779296875, "max": 0.8064373779296875}}}
#
# #metrics {"StartTime": 1631013785.7480855, "EndTime": 1631013785.7480967, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.5465533828735352, "count": 1, "min": 0.5465533828735352, "max": 0.5465533828735352}}}
#
# #metrics {"StartTime": 1631013785.7481523, "EndTime": 1631013785.748163, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.3532223892211914, "count": 1, "min": 0.3532223892211914, "max": 0.3532223892211914}}}
#
# #metrics {"StartTime": 1631013785.7481968, "EndTime": 1631013785.748206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.4450480270385742, "count": 1, "min": 0.4450480270385742, "max": 0.4450480270385742}}}
#
# #metrics {"StartTime": 1631013785.7482383, "EndTime": 1631013785.7482476, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.47368152618408205, "count": 1, "min": 0.47368152618408205, "max": 0.47368152618408205}}}
#
# #metrics {"StartTime": 1631013785.7483003, "EndTime": 1631013785.7483118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.8542903137207031, "count": 1, "min": 0.8542903137207031, "max": 0.8542903137207031}}}
#
# #metrics {"StartTime": 1631013785.7483745, "EndTime": 1631013785.7483869, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.3879588317871094, "count": 1, "min": 1.3879588317871094, "max": 1.3879588317871094}}}
#
# #metrics {"StartTime": 1631013785.7484474, "EndTime": 1631013785.7484608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.7707237243652344, "count": 1, "min": 0.7707237243652344, "max": 0.7707237243652344}}}
#
# #metrics {"StartTime": 1631013785.7485015, "EndTime": 1631013785.7485304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.0179505157470703, "count": 1, "min": 1.0179505157470703, "max": 1.0179505157470703}}}
#
# #metrics {"StartTime": 1631013785.748572, "EndTime": 1631013785.7485824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.4537581253051758, "count": 1, "min": 0.4537581253051758, "max": 0.4537581253051758}}}
#
# #metrics {"StartTime": 1631013785.7486203, "EndTime": 1631013785.7486298, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.5117273330688477, "count": 1, "min": 0.5117273330688477, "max": 0.5117273330688477}}}
#
# #metrics {"StartTime": 1631013785.7486656, "EndTime": 1631013785.7486749, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.5314524841308593, "count": 1, "min": 0.5314524841308593, "max": 0.5314524841308593}}}
#
# #metrics {"StartTime": 1631013785.748728, "EndTime": 1631013785.7487407, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.39173526763916017, "count": 1, "min": 0.39173526763916017, "max": 0.39173526763916017}}}
#
# #metrics {"StartTime": 1631013785.7488046, "EndTime": 1631013785.7488167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.9968754577636719, "count": 1, "min": 0.9968754577636719, "max": 0.9968754577636719}}}
#
# #metrics {"StartTime": 1631013785.7488785, "EndTime": 1631013785.748891, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7345633697509766, "count": 1, "min": 0.7345633697509766, "max": 0.7345633697509766}}}
#
# #metrics {"StartTime": 1631013785.748946, "EndTime": 1631013785.748961, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.1964578247070312, "count": 1, "min": 1.1964578247070312, "max": 1.1964578247070312}}}
#
# #metrics {"StartTime": 1631013785.7490027, "EndTime": 1631013785.7490127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 1.025803985595703, "count": 1, "min": 1.025803985595703, "max": 1.025803985595703}}}
#
# #metrics {"StartTime": 1631013785.7490509, "EndTime": 1631013785.7490606, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.554821434020996, "count": 1, "min": 0.554821434020996, "max": 0.554821434020996}}}
#
# #metrics {"StartTime": 1631013785.7490954, "EndTime": 1631013785.7491052, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.42866863250732423, "count": 1, "min": 0.42866863250732423, "max": 0.42866863250732423}}}
#
# #metrics {"StartTime": 1631013785.7491589, "EndTime": 1631013785.7491715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.4370318603515625, "count": 1, "min": 0.4370318603515625, "max": 0.4370318603515625}}}
#
# #metrics {"StartTime": 1631013785.749236, "EndTime": 1631013785.7492487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.4350708770751953, "count": 1, "min": 0.4350708770751953, "max": 0.4350708770751953}}}
#
# #metrics {"StartTime": 1631013785.7493122, "EndTime": 1631013785.7493246, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.969595947265625, "count": 1, "min": 0.969595947265625, "max": 0.969595947265625}}}
#
# #metrics {"StartTime": 1631013785.7493832, "EndTime": 1631013785.749396, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9613291168212891, "count": 1, "min": 0.9613291168212891, "max": 0.9613291168212891}}}
#
# #metrics {"StartTime": 1631013785.7494373, "EndTime": 1631013785.7494485, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.2184191131591797, "count": 1, "min": 1.2184191131591797, "max": 1.2184191131591797}}}
#
# #metrics {"StartTime": 1631013785.7494855, "EndTime": 1631013785.7494948, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.1237201690673828, "count": 1, "min": 1.1237201690673828, "max": 1.1237201690673828}}}
#
# #metrics {"StartTime": 1631013785.7495303, "EndTime": 1631013785.7495403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0198078918457032, "count": 1, "min": 1.0198078918457032, "max": 1.0198078918457032}}}
#
# #metrics {"StartTime": 1631013785.7495947, "EndTime": 1631013785.7496066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.272796630859375, "count": 1, "min": 1.272796630859375, "max": 1.272796630859375}}}
#
# #metrics {"StartTime": 1631013785.7496684, "EndTime": 1631013785.7496808, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.7945167541503906, "count": 1, "min": 0.7945167541503906, "max": 0.7945167541503906}}}
#
# #metrics {"StartTime": 1631013785.749936, "EndTime": 1631013785.7499537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.6497319030761719, "count": 1, "min": 0.6497319030761719, "max": 0.6497319030761719}}}
#
# [09/07/2021 11:23:05 INFO 140674731267904] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.8900357818603516
# #metrics {"StartTime": 1631013785.8088827, "EndTime": 1631013785.8089666, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 1.0271474520365398, "count": 1, "min": 1.0271474520365398, "max": 1.0271474520365398}}}
#
# #metrics {"StartTime": 1631013785.8090634, "EndTime": 1631013785.80908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 0.9869062900543213, "count": 1, "min": 0.9869062900543213, "max": 0.9869062900543213}}}
#
# #metrics {"StartTime": 1631013785.809125, "EndTime": 1631013785.8091562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 1.3507668177286785, "count": 1, "min": 1.3507668177286785, "max": 1.3507668177286785}}}
#
# #metrics {"StartTime": 1631013785.809199, "EndTime": 1631013785.8092291, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 0.990259567896525, "count": 1, "min": 0.990259567896525, "max": 0.990259567896525}}}
#
# #metrics {"StartTime": 1631013785.8092716, "EndTime": 1631013785.8092818, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 1.289949893951416, "count": 1, "min": 1.289949893951416, "max": 1.289949893951416}}}
#
# #metrics {"StartTime": 1631013785.8093374, "EndTime": 1631013785.809348, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 1.307513952255249, "count": 1, "min": 1.307513952255249, "max": 1.307513952255249}}}
#
# #metrics {"StartTime": 1631013785.8093815, "EndTime": 1631013785.8093903, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 1.4671532313028972, "count": 1, "min": 1.4671532313028972, "max": 1.4671532313028972}}}
#
# #metrics {"StartTime": 1631013785.809442, "EndTime": 1631013785.8094537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 1.4194467862447102, "count": 1, "min": 1.4194467862447102, "max": 1.4194467862447102}}}
#
# #metrics {"StartTime": 1631013785.8095143, "EndTime": 1631013785.809528, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 1.1221850713094075, "count": 1, "min": 1.1221850713094075, "max": 1.1221850713094075}}}
#
# #metrics {"StartTime": 1631013785.8095708, "EndTime": 1631013785.8096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 1.4429965019226074, "count": 1, "min": 1.4429965019226074, "max": 1.4429965019226074}}}
#
# #metrics {"StartTime": 1631013785.8096433, "EndTime": 1631013785.8096542, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 1.0281309286753337, "count": 1, "min": 1.0281309286753337, "max": 1.0281309286753337}}}
#
# #metrics {"StartTime": 1631013785.809708, "EndTime": 1631013785.809719, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 1.2000854810078938, "count": 1, "min": 1.2000854810078938, "max": 1.2000854810078938}}}
#
# #metrics {"StartTime": 1631013785.8097575, "EndTime": 1631013785.809766, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 1.4097426732381184, "count": 1, "min": 1.4097426732381184, "max": 1.4097426732381184}}}
#
# #metrics {"StartTime": 1631013785.809805, "EndTime": 1631013785.8098314, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 1.4188989003499348, "count": 1, "min": 1.4188989003499348, "max": 1.4188989003499348}}}
#
# #metrics {"StartTime": 1631013785.8098745, "EndTime": 1631013785.8099065, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 1.3776183128356934, "count": 1, "min": 1.3776183128356934, "max": 1.3776183128356934}}}
#
# #metrics {"StartTime": 1631013785.8099496, "EndTime": 1631013785.8099806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 1.359721024831136, "count": 1, "min": 1.359721024831136, "max": 1.359721024831136}}}
#
# #metrics {"StartTime": 1631013785.8100226, "EndTime": 1631013785.8100336, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 1.1525992552439372, "count": 1, "min": 1.1525992552439372, "max": 1.1525992552439372}}}
#
# #metrics {"StartTime": 1631013785.8100924, "EndTime": 1631013785.8101044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.9994086424509684, "count": 1, "min": 0.9994086424509684, "max": 0.9994086424509684}}}
#
# #metrics {"StartTime": 1631013785.8101432, "EndTime": 1631013785.810153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 1.3556283315022786, "count": 1, "min": 1.3556283315022786, "max": 1.3556283315022786}}}
#
# #metrics {"StartTime": 1631013785.810189, "EndTime": 1631013785.8102, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 1.1288548310597737, "count": 1, "min": 1.1288548310597737, "max": 1.1288548310597737}}}
#
# #metrics {"StartTime": 1631013785.8102543, "EndTime": 1631013785.8102672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 1.21407151222229, "count": 1, "min": 1.21407151222229, "max": 1.21407151222229}}}
#
# #metrics {"StartTime": 1631013785.8103495, "EndTime": 1631013785.8103619, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 1.3254947662353516, "count": 1, "min": 1.3254947662353516, "max": 1.3254947662353516}}}
#
# #metrics {"StartTime": 1631013785.810424, "EndTime": 1631013785.8104348, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 1.2018145720163982, "count": 1, "min": 1.2018145720163982, "max": 1.2018145720163982}}}
#
# #metrics {"StartTime": 1631013785.8104944, "EndTime": 1631013785.8105066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 1.2412665685017903, "count": 1, "min": 1.2412665685017903, "max": 1.2412665685017903}}}
#
# #metrics {"StartTime": 1631013785.810546, "EndTime": 1631013785.810556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 1.1268339157104492, "count": 1, "min": 1.1268339157104492, "max": 1.1268339157104492}}}
#
# #metrics {"StartTime": 1631013785.8105915, "EndTime": 1631013785.810601, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 1.1702931722005208, "count": 1, "min": 1.1702931722005208, "max": 1.1702931722005208}}}
#
# #metrics {"StartTime": 1631013785.8106563, "EndTime": 1631013785.8106685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 1.296300967534383, "count": 1, "min": 1.296300967534383, "max": 1.296300967534383}}}
#
# #metrics {"StartTime": 1631013785.8107326, "EndTime": 1631013785.8107443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 1.3109735647837322, "count": 1, "min": 1.3109735647837322, "max": 1.3109735647837322}}}
#
# #metrics {"StartTime": 1631013785.810807, "EndTime": 1631013785.8108191, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 1.7273066838582356, "count": 1, "min": 1.7273066838582356, "max": 1.7273066838582356}}}
#
# #metrics {"StartTime": 1631013785.8108773, "EndTime": 1631013785.81089, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 1.7701838811238606, "count": 1, "min": 1.7701838811238606, "max": 1.7701838811238606}}}
#
# ...
#
# #metrics {"StartTime": 1631013787.9979177, "EndTime": 1631013787.997933, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.062867202758789, "count": 1, "min": 1.062867202758789, "max": 1.062867202758789}}}
#
# #metrics {"StartTime": 1631013787.9981055, "EndTime": 1631013787.9981213, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9486235046386718, "count": 1, "min": 0.9486235046386718, "max": 0.9486235046386718}}}
#
# #metrics {"StartTime": 1631013787.9981818, "EndTime": 1631013787.9981952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.1451493835449218, "count": 1, "min": 1.1451493835449218, "max": 1.1451493835449218}}}
#
# #metrics {"StartTime": 1631013787.9983082, "EndTime": 1631013787.9983392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.1511328887939454, "count": 1, "min": 1.1511328887939454, "max": 1.1511328887939454}}}
#
# [09/07/2021 11:23:07 INFO 140674731267904] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.43258071899414063
# #metrics {"StartTime": 1631013788.0830271, "EndTime": 1631013788.083123, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 0.6774826844533285, "count": 1, "min": 0.6774826844533285, "max": 0.6774826844533285}}}
#
# #metrics {"StartTime": 1631013788.083226, "EndTime": 1631013788.0838223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 0.6807112693786621, "count": 1, "min": 0.6807112693786621, "max": 0.6807112693786621}}}
#
# #metrics {"StartTime": 1631013788.0842285, "EndTime": 1631013788.0842607, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 0.8238527774810791, "count": 1, "min": 0.8238527774810791, "max": 0.8238527774810791}}}
#
# #metrics {"StartTime": 1631013788.0846303, "EndTime": 1631013788.084657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 0.6803070704142252, "count": 1, "min": 0.6803070704142252, "max": 0.6803070704142252}}}
#
# #metrics {"StartTime": 1631013788.0849066, "EndTime": 1631013788.0849507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 0.4574044545491536, "count": 1, "min": 0.4574044545491536, "max": 0.4574044545491536}}}
#
# #metrics {"StartTime": 1631013788.0853004, "EndTime": 1631013788.085329, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 0.49996598561604816, "count": 1, "min": 0.49996598561604816, "max": 0.49996598561604816}}}
#
# #metrics {"StartTime": 1631013788.0856671, "EndTime": 1631013788.0857196, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 0.5163917541503906, "count": 1, "min": 0.5163917541503906, "max": 0.5163917541503906}}}
#
# #metrics {"StartTime": 1631013788.086073, "EndTime": 1631013788.0860984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 0.518569270769755, "count": 1, "min": 0.518569270769755, "max": 0.518569270769755}}}
#
# #metrics {"StartTime": 1631013788.0864713, "EndTime": 1631013788.0864973, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 0.8061532179514567, "count": 1, "min": 0.8061532179514567, "max": 0.8061532179514567}}}
#
# #metrics {"StartTime": 1631013788.0867798, "EndTime": 1631013788.0868707, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 0.8760004838307699, "count": 1, "min": 0.8760004838307699, "max": 0.8760004838307699}}}
#
# #metrics {"StartTime": 1631013788.0871928, "EndTime": 1631013788.087215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 0.7383246421813965, "count": 1, "min": 0.7383246421813965, "max": 0.7383246421813965}}}
#
# #metrics {"StartTime": 1631013788.0875351, "EndTime": 1631013788.0875573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 0.798662265141805, "count": 1, "min": 0.798662265141805, "max": 0.798662265141805}}}
#
# #metrics {"StartTime": 1631013788.0878813, "EndTime": 1631013788.0879061, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 0.4578196207682292, "count": 1, "min": 0.4578196207682292, "max": 0.4578196207682292}}}
#
# #metrics {"StartTime": 1631013788.0882254, "EndTime": 1631013788.0882485, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 0.46722503503163654, "count": 1, "min": 0.46722503503163654, "max": 0.46722503503163654}}}
#
# #metrics {"StartTime": 1631013788.0885847, "EndTime": 1631013788.0886078, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 0.4838241736094157, "count": 1, "min": 0.4838241736094157, "max": 0.4838241736094157}}}
#
# #metrics {"StartTime": 1631013788.0889583, "EndTime": 1631013788.0889807, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 0.5058112541834513, "count": 1, "min": 0.5058112541834513, "max": 0.5058112541834513}}}
#
# #metrics {"StartTime": 1631013788.0893042, "EndTime": 1631013788.0893269, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 0.7590286731719971, "count": 1, "min": 0.7590286731719971, "max": 0.7590286731719971}}}
#
# #metrics {"StartTime": 1631013788.0896285, "EndTime": 1631013788.0896506, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 0.7145383358001709, "count": 1, "min": 0.7145383358001709, "max": 0.7145383358001709}}}
#
# #metrics {"StartTime": 1631013788.0899699, "EndTime": 1631013788.0899913, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 0.9076029459635416, "count": 1, "min": 0.9076029459635416, "max": 0.9076029459635416}}}
#
# #metrics {"StartTime": 1631013788.090293, "EndTime": 1631013788.0903153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 0.7586540381113688, "count": 1, "min": 0.7586540381113688, "max": 0.7586540381113688}}}
#
# #metrics {"StartTime": 1631013788.0906348, "EndTime": 1631013788.0906568, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 0.5701437393824259, "count": 1, "min": 0.5701437393824259, "max": 0.5701437393824259}}}
#
# #metrics {"StartTime": 1631013788.0909634, "EndTime": 1631013788.0909858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 0.4661986033121745, "count": 1, "min": 0.4661986033121745, "max": 0.4661986033121745}}}
#
# #metrics {"StartTime": 1631013788.0912635, "EndTime": 1631013788.0912855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 0.5680944522221884, "count": 1, "min": 0.5680944522221884, "max": 0.5680944522221884}}}
#
# #metrics {"StartTime": 1631013788.0916104, "EndTime": 1631013788.0916345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 0.5475363731384277, "count": 1, "min": 0.5475363731384277, "max": 0.5475363731384277}}}
#
# #metrics {"StartTime": 1631013788.0919516, "EndTime": 1631013788.0919733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 1.1521388689676921, "count": 1, "min": 1.1521388689676921, "max": 1.1521388689676921}}}
#
# #metrics {"StartTime": 1631013788.0922945, "EndTime": 1631013788.092318, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 1.1101908683776855, "count": 1, "min": 1.1101908683776855, "max": 1.1101908683776855}}}
#
# #metrics {"StartTime": 1631013788.092668, "EndTime": 1631013788.0926924, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 1.080248196919759, "count": 1, "min": 1.080248196919759, "max": 1.080248196919759}}}
#
# #metrics {"StartTime": 1631013788.093073, "EndTime": 1631013788.093097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 1.108044147491455, "count": 1, "min": 1.108044147491455, "max": 1.108044147491455}}}
#
# #metrics {"StartTime": 1631013788.0936873, "EndTime": 1631013788.0937364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 1.1432851950327556, "count": 1, "min": 1.1432851950327556, "max": 1.1432851950327556}}}
#
# #metrics {"StartTime": 1631013788.0941105, "EndTime": 1631013788.0941381, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 1.112316608428955, "count": 1, "min": 1.112316608428955, "max": 1.112316608428955}}}
#
# #metrics {"StartTime": 1631013788.094443, "EndTime": 1631013788.0944858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 1.1728923320770264, "count": 1, "min": 1.1728923320770264, "max": 1.1728923320770264}}}
#
# #metrics {"StartTime": 1631013788.09494, "EndTime": 1631013788.094969, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 1.158691167831421, "count": 1, "min": 1.158691167831421, "max": 1.158691167831421}}}
#
# [09/07/2021 11:23:08 INFO 140674731267904] #quality_metric: host=algo-1, epoch=14, validation mse_objective <loss>=0.6774826844533285
# [09/07/2021 11:23:08 INFO 140674731267904] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.4574044545491536
# [09/07/2021 11:23:08 INFO 140674731267904] Saving model for epoch: 14
# [09/07/2021 11:23:08 INFO 140674731267904] Saved checkpoint to "/tmp/tmphzhl4x5p/mx-mod-0000.params"
# [09/07/2021 11:23:08 INFO 140674731267904] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1631013787.9466624, "EndTime": 1631013788.1049209, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3204.0, "count": 1, "min": 3204, "max": 3204}, "Total Batches Seen": {"sum": 33.0, "count": 1, "min": 33, "max": 33}, "Max Records Seen Between Resets": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 194.0, "count": 1, "min": 194, "max": 194}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
#
# [09/07/2021 11:23:08 INFO 140674731267904] #throughput_metric: host=algo-1, train throughput=1223.5554693432578 records/second
# [09/07/2021 11:23:08 WARNING 140674731267904] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/07/2021 11:23:08 WARNING 140674731267904] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/07/2021 11:23:08 INFO 140674731267904] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.4574044545491536
# [09/07/2021 11:23:08 INFO 140674731267904] #validation_score (algo-1) : ('mse_objective', 0.3980878988901774)
# [09/07/2021 11:23:08 INFO 140674731267904] #validation_score (algo-1) : ('mse', 0.3980878988901774)
# [09/07/2021 11:23:08 INFO 140674731267904] #validation_score (algo-1) : ('absolute_loss', 0.40454145272572833)
# [09/07/2021 11:23:08 INFO 140674731267904] #quality_metric: host=algo-1, validation mse_objective <loss>=0.3980878988901774
# [09/07/2021 11:23:08 INFO 140674731267904] #quality_metric: host=algo-1, validation mse <loss>=0.3980878988901774
# [09/07/2021 11:23:08 INFO 140674731267904] #quality_metric: host=algo-1, validation absolute_loss <loss>=0.40454145272572833
# [09/07/2021 11:23:08 INFO 140674731267904] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 1, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [09/07/2021 11:23:08 INFO 140674731267904] Saved checkpoint to "/tmp/tmpegbt0ssv/mx-mod-0000.params"
# [09/07/2021 11:23:08 INFO 140674731267904] Test data is not provided.
# #metrics {"StartTime": 1631013785.4719126, "EndTime": 1631013788.2161446, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 141.4649486541748, "count": 1, "min": 141.4649486541748, "max": 141.4649486541748}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 14.312744140625, "count": 16, "min": 0.2009868621826172, "max": 2.8839111328125}, "update.time": {"sum": 2381.4921379089355, "count": 15, "min": 90.43550491333008, "max": 270.843505859375}, "finalize.time": {"sum": 102.20527648925781, "count": 1, "min": 102.20527648925781, "max": 102.20527648925781}, "setuptime": {"sum": 25.26545524597168, "count": 1, "min": 25.26545524597168, "max": 25.26545524597168}, "totaltime": {"sum": 2957.4873447418213, "count": 1, "min": 2957.4873447418213, "max": 2957.4873447418213}}}
#
#
# 2021-09-07 11:23:31 Uploading - Uploading generated training model
# 2021-09-07 11:23:31 Completed - Training job completed
# Training seconds: 74
# Billable seconds: 74

# %% [markdown]
# ## Deploy the model

# %% [markdown]
# To deploy from the same notebook instance, we can just use the deploy method on the model interface.
#
# This will:
#
# - Register the trained model in SageMaker (check it!)
# - Create an endpoint configuration with the instance specification we just sent
# - Create the real-time endpoint

# %%
linear_predictor = model.deploy(initial_instance_count=1, instance_type="ml.m4.xlarge")
# Out:
# -----------------!

# %% [markdown]
# ## Test the endpoint

# %% [markdown]
# Now we have an endpoint to call. There are multiple ways to interact with a deployed model, but the mains are:
#
# - Using the Sagemaker SDK (through the model interface as we will do now or with the sagemaker runtime a the next lab)
# - Through a request (lab 7)
#
# An endpoint in the very end is just a load balancing that redirects your request to the model, runs it, and returns the prediction. It also sends metrics to cloudwatch for monitoring and autoscaling.

# %%
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer

linear_predictor.serializer = CSVSerializer()
linear_predictor.deserializer = JSONDeserializer()

# %% [markdown]
# To interact with the model interface in the SDK, use the predictor.predict method. The predictor is the output of the deploy method on the model.

# %%
test_set = pd.concat([X_test, Y_test], axis=1)

def get_predictions(x):
    row = x.values
    return linear_predictor.predict(row[1:], initial_args={"ContentType": "text/csv"})['predictions'][0]['score']
    
test_set['predictions'] = test_set.apply(get_predictions, axis=1)  # This could be done all at once too!
# Out:
# [-0.34810887 -0.51359612  0.52386114  3.54876739  0.11542494 -0.67306156
#  -0.3133354  -0.40632946 -0.1364601  -0.65862219 -0.91322502  0.33189817
#   0.31289493 -0.03083003]
# {'predictions': [{'score': -0.4846033453941345}]}

# %%
test_set
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 313 -0.347407  0.982243 -0.638071 -0.281788 -0.936577 -0.940181 -1.298120
# 249 -0.267329  0.341169 -0.948216 -0.281788  0.350037  2.862596  0.079151
# 162 -0.346797 -0.513596 -0.936344 -0.281788 -0.259955 -0.046359  0.307507
# 293 -0.235172 -0.513596 -0.068234 -0.281788  0.059118 -0.329623 -0.427513
# 371  0.709822 -0.513596  1.148603 -0.281788  1.692020 -0.499875  1.088913
# ..        ...       ...       ...       ...       ...       ...       ...
# 49  -0.346896  0.383908 -0.700396 -0.281788 -0.926254  0.241307 -1.558589
# 257 -0.340461  1.195935 -0.586132 -0.281788 -0.851178  0.744724 -0.784319
# 124 -0.221398 -0.513596  1.711020 -0.281788  0.809877 -1.041451  1.067504
# 80  -0.347352 -0.513596 -0.871051 -0.281788 -0.832409  0.062250 -0.598780
# 273 -0.343066  2.905466 -0.802789 -0.281788 -1.189020  1.176224 -1.323097
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT     PRICE  \
# 313  1.074211 -0.224991 -0.480898 -0.677403  0.358558  0.139964 -0.731324
# 249 -0.696052 -0.136460 -0.734790 -2.516815  0.151400 -0.659040  2.985812
# 162 -0.320147 -0.136460 -0.531676 -0.818896  0.393084 -0.843179  0.116048
# 293 -0.604289 -0.158593 -0.480898  0.030063  0.421491 -0.892817 -0.166409
# 371 -0.925564  0.284063  1.816825  0.879023 -1.259367  0.663560 -1.058974
# ..        ...       ...       ...       ...       ...       ...       ...
# 49   1.147219 -0.158593 -0.868083 -0.724567  0.421491 -1.004901  0.161241
# 257  0.078373 -0.158593 -0.798263 -0.347252  0.421491 -1.373180  0.952121
# 124 -0.881381 -0.158593  0.363293  1.350667  0.421491  1.086280 -1.047676
# 80   0.293241 -0.180726 -0.842694  0.077228  0.421491 -0.309976  0.036960
# 273  0.434767 -0.158593 -0.855389  0.407379  0.421491 -1.280309  1.550930
#
#      predictions
# 313    -0.733373
# 249    -0.738268
# 162    -0.210224
# 293    -0.387766
# 371     1.452641
# ..           ...
# 49     -1.099835
# 257    -0.922804
# 124     0.696246
# 80     -0.676379
# 273    -1.372654
#
# [143 rows x 15 columns]

# %% [markdown]
# Let's calculate the error on the predictions. It is very difficult to measure how good a regression model is, you are usually happy comparing how far the predictions are.

# %%
import numpy as np
np.sum((test_set['PRICE'] - test_set['predictions'])**2)
# Out:
# 390.00436487470466

# %% [markdown]
# ## Delete the model

# %% [markdown]
# Never forget to delete your resources once you are done!

# %%
linear_predictor.delete_model()
linear_predictor.delete_endpoint()
